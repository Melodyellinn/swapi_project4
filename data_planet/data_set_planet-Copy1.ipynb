# %%
import requests
import pandas as pd

# %%
uri = 'https://swapi.dev/api/planets/'

# %%
def fetch_planets(n_planets):
    uri = 'https://swapi.dev/api/planets/'
    url = f'{uri}/{str(n_planets)}'
    r = requests.get(url)
    data = r.json()
    return data

# %%
def datasetplanet(planets_list, planet_df, n_planets):
    planet_df.loc[n_planets,'name'] = planets_list['name']
    planet_df.loc[n_planets,'rotation_period'] = planets_list['rotation_period']
    planet_df.loc[n_planets,'orbital_period'] = planets_list['orbital_period']
    planet_df.loc[n_planets,'diameter'] = planets_list['diameter']
    planet_df.loc[n_planets,'climate'] = planets_list['climate']
    planet_df.loc[n_planets,'gravity'] = planets_list['gravity']
    planet_df.loc[n_planets,'terrain'] = planets_list['terrain']
    planet_df.loc[n_planets,'surface_water'] = planets_list['surface_water']
    planet_df.loc[n_planets,'population'] = planets_list['population']
    return planet_df

# %%
columns = ['name','rotation_period','orbital_period','diameter','climate','gravity','terrain','surface_water','population']
planet_df = pd.DataFrame(columns=columns)

n = 60

for i in range (1,n+1):
    planets_list = fetch_planets(i)
    planet_df = datasetplanet(planets_list, planet_df,i)
planet_df
# Out:
#               name rotation_period orbital_period diameter  \
# 1         Tatooine              23            304    10465
# 2         Alderaan              24            364    12500
# 3         Yavin IV              24           4818    10200
# 4             Hoth              23            549     7200
# 5          Dagobah              23            341     8900
# 6           Bespin              12           5110   118000
# 7            Endor              18            402     4900
# 8            Naboo              26            312    12120
# 9        Coruscant              24            368    12240
# 10          Kamino              27            463    19720
# 11        Geonosis              30            256    11370
# 12          Utapau              27            351    12900
# 13        Mustafar              36            412     4200
# 14        Kashyyyk              26            381    12765
# 15     Polis Massa              24            590        0
# 16         Mygeeto              12            167    10088
# 17         Felucia              34            231     9100
# 18  Cato Neimoidia              25            278        0
# 19       Saleucami              26            392    14920
# 20         Stewjon         unknown        unknown        0
# 21          Eriadu              24            360    13490
# 22        Corellia              25            329    11000
# 23           Rodia              29            305     7549
# 24       Nal Hutta              87            413    12150
# 25       Dantooine              25            378     9830
# 26      Bestine IV              26            680     6400
# 27     Ord Mantell              26            334    14050
# 28         unknown               0              0        0
# 29       Trandosha              25            371        0
# 30         Socorro              20            326        0
# 31        Mon Cala              21            398    11030
# 32       Chandrila              20            368    13500
# 33         Sullust              20            263    12780
# 34        Toydaria              21            184     7900
# 35       Malastare              26            201    18880
# 36        Dathomir              24            491    10480
# 37          Ryloth              30            305    10600
# 38     Aleen Minor         unknown        unknown  unknown
# 39         Vulpter              22            391    14900
# 40         Troiken         unknown        unknown  unknown
# 41            Tund              48           1770    12190
# 42      Haruun Kal              25            383    10120
# 43           Cerea              27            386  unknown
# 44     Glee Anselm              33            206    15600
# 45        Iridonia              29            413  unknown
# 46         Tholoth         unknown        unknown  unknown
# 47         Iktotch              22            481  unknown
# 48         Quermia         unknown        unknown  unknown
# 49           Dorin              22            409    13400
# 50        Champala              27            318  unknown
# 51          Mirial         unknown        unknown  unknown
# 52         Serenno         unknown        unknown  unknown
# 53    Concord Dawn         unknown        unknown  unknown
# 54           Zolan         unknown        unknown  unknown
# 55            Ojom         unknown        unknown  unknown
# 56           Skako              27            384  unknown
# 57      Muunilinst              28            412    13800
# 58           Shili         unknown        unknown  unknown
# 59           Kalee              23            378    13850
# 60          Umbara         unknown        unknown  unknown
#
#                       climate                                 gravity  \
# 1                        arid                              1 standard
# 2                   temperate                              1 standard
# 3         temperate, tropical                              1 standard
# 4                      frozen                            1.1 standard
# 5                       murky                                     N/A
# 6                   temperate  1.5 (surface), 1 standard (Cloud City)
# 7                   temperate                           0.85 standard
# 8                   temperate                              1 standard
# 9                   temperate                              1 standard
# 10                  temperate                              1 standard
# 11            temperate, arid                            0.9 standard
# 12     temperate, arid, windy                              1 standard
# 13                        hot                              1 standard
# 14                   tropical                              1 standard
# 15      artificial temperate                            0.56 standard
# 16                     frigid                              1 standard
# 17                 hot, humid                           0.75 standard
# 18           temperate, moist                              1 standard
# 19                        hot                                 unknown
# 20                  temperate                              1 standard
# 21                   polluted                              1 standard
# 22                  temperate                              1 standard
# 23                        hot                              1 standard
# 24                  temperate                              1 standard
# 25                  temperate                              1 standard
# 26                  temperate                                 unknown
# 27                  temperate                              1 standard
# 28                    unknown                                 unknown
# 29                       arid                           0.62 standard
# 30                       arid                              1 standard
# 31                  temperate                                       1
# 32                  temperate                                       1
# 33                superheated                                       1
# 34                  temperate                                       1
# 35  arid, temperate, tropical                                    1.56
# 36                  temperate                                     0.9
# 37  temperate, arid, subartic                                       1
# 38                    unknown                                 unknown
# 39           temperate, artic                                       1
# 40                    unknown                                 unknown
# 41                    unknown                                 unknown
# 42                  temperate                                    0.98
# 43                  temperate                                       1
# 44        tropical, temperate                                       1
# 45                    unknown                                 unknown
# 46                    unknown                                 unknown
# 47         arid, rocky, windy                                       1
# 48                    unknown                                 unknown
# 49                  temperate                                       1
# 50                  temperate                                       1
# 51                    unknown                                 unknown
# 52                    unknown                                 unknown
# 53                    unknown                                 unknown
# 54                    unknown                                 unknown
# 55                     frigid                                 unknown
# 56                  temperate                                       1
# 57                  temperate                                       1
# 58                  temperate                                       1
# 59  arid, temperate, tropical                                       1
# 60                    unknown                                 unknown
#
#                                      terrain surface_water     population
# 1                                     desert             1         200000
# 2                      grasslands, mountains            40     2000000000
# 3                        jungle, rainforests             8           1000
# 4         tundra, ice caves, mountain ranges           100        unknown
# 5                             swamp, jungles             8        unknown
# 6                                  gas giant             0        6000000
# 7                  forests, mountains, lakes             8       30000000
# 8   grassy hills, swamps, forests, mountains            12     4500000000
# 9                       cityscape, mountains       unknown  1000000000000
# 10                                     ocean           100     1000000000
# 11            rock, desert, mountain, barren             5   100000000000
# 12   scrublands, savanna, canyons, sinkholes           0.9       95000000
# 13  volcanoes, lava rivers, mountains, caves             0          20000
# 14            jungle, forests, lakes, rivers            60       45000000
# 15                          airless asteroid             0        1000000
# 16          glaciers, mountains, ice canyons       unknown       19000000
# 17                            fungus forests       unknown        8500000
# 18   mountains, fields, forests, rock arches       unknown       10000000
# 19       caves, desert, mountains, volcanoes       unknown     1400000000
# 20                                     grass       unknown        unknown
# 21                                 cityscape       unknown    22000000000
# 22             plains, urban, hills, forests            70     3000000000
# 23            jungles, oceans, urban, swamps            60     1300000000
# 24               urban, oceans, swamps, bogs       unknown     7000000000
# 25   oceans, savannas, mountains, grasslands       unknown           1000
# 26                     rocky islands, oceans            98       62000000
# 27                       plains, seas, mesas            10     4000000000
# 28                                   unknown       unknown        unknown
# 29      mountains, seas, grasslands, deserts       unknown       42000000
# 30                        deserts, mountains       unknown      300000000
# 31                    oceans, reefs, islands           100    27000000000
# 32                           plains, forests            40     1200000000
# 33       mountains, volcanoes, rocky deserts             5    18500000000
# 34                             swamps, lakes       unknown       11000000
# 35       swamps, deserts, jungles, mountains       unknown     2000000000
# 36                forests, deserts, savannas       unknown           5200
# 37       mountains, valleys, deserts, tundra             5     1500000000
# 38                                   unknown       unknown        unknown
# 39                             urban, barren       unknown      421000000
# 40    desert, tundra, rainforests, mountains       unknown        unknown
# 41                               barren, ash       unknown              0
# 42       toxic cloudsea, plateaus, volcanoes       unknown         705300
# 43                                   verdant            20      450000000
# 44              lakes, islands, swamps, seas            80      500000000
# 45                 rocky canyons, acid pools       unknown        unknown
# 46                                   unknown       unknown        unknown
# 47                                     rocky       unknown        unknown
# 48                                   unknown       unknown        unknown
# 49                                   unknown       unknown        unknown
# 50             oceans, rainforests, plateaus       unknown     3500000000
# 51                                   deserts       unknown        unknown
# 52            rainforests, rivers, mountains       unknown        unknown
# 53                 jungles, forests, deserts       unknown        unknown
# 54                                   unknown       unknown        unknown
# 55                          oceans, glaciers           100      500000000
# 56                              urban, vines       unknown   500000000000
# 57         plains, forests, hills, mountains            25     5000000000
# 58           cities, savannahs, seas, plains       unknown        unknown
# 59        rainforests, cliffs, canyons, seas       unknown     4000000000
# 60                                   unknown       unknown        unknown
